# %%
import wandb
from configs.defaults import Globs
from helpers.wandb_common import get_wandb_df

# %%
df = get_wandb_df(project_name=Globs.project_name,
                  wandb_user=Globs.entity_name)

# %%
filter_tags = ['tuning', 'v3']
for filter_tag in filter_tags:
    df = df[df.tags.apply(lambda x: filter_tag in x)]

# %%
df.head(3)
# Out:
#          id          tags        lr norm MODEL    DATASET   dropout  \
# 3  3srkg3me  [tuning, v3]  0.003146  NaN   rnn  synthetic  0.076969
# 4  11vjjtr5  [tuning, v3]  0.059171  NaN   rnn  synthetic  0.107910
# 5  1eucduit  [tuning, v3]  0.004100  NaN   rnn  synthetic  0.140801
#
#    batch_size  drop_input  hidden_size  ...  finalrho-0.25  finalrho2-0.1  \
# 3       128.0         NaN        120.0  ...            NaN            NaN
# 4       128.0         NaN        126.0  ...            NaN            NaN
# 5       128.0         NaN        116.0  ...            NaN            NaN
#
#   finalrho2-0.5  finalrho2-0.75  finalrho-0.1  finalrho2-0.98 finalrho-0.75  \
# 3           NaN             NaN           NaN             NaN           NaN
# 4           NaN             NaN           NaN             NaN           NaN
# 5           NaN             NaN           NaN             NaN           NaN
#
#   finalrho2-0.9 finalrho2-0.02 finalrho2-0.25
# ...

# %%
datasets, models = list(df['DATASET'].unique()), list(df['MODEL'].unique())

# %%
# Results for the top 3 hyperparams
df.groupby(['DATASET', 'MODEL'])['final_NRMSE', 'final_ND'].apply(lambda x: x.nsmallest(3, ['final_ND']))\
    .groupby(['DATASET', 'MODEL'])['final_NRMSE', 'final_ND'].agg(['std'])
# Out:
# /tmp/ipykernel_4153/826817506.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['DATASET', 'MODEL'])['final_NRMSE', 'final_ND'].apply(lambda x: x.nsmallest(3, ['final_ND']))\
# /tmp/ipykernel_4153/826817506.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['DATASET', 'MODEL'])['final_NRMSE', 'final_ND'].apply(lambda x: x.nsmallest(3, ['final_ND']))\
#                       final_NRMSE  final_ND
#                               std       std
# DATASET   MODEL
# rossmann  mlp            0.000455  0.000032
#           polar_dense    0.000665  0.000259
#           polar_rnn      0.001781  0.000839
#           rnn            0.001293  0.000983
# synthetic mlp            0.000083  0.000074
#           polar_dense    0.001742  0.001897
#           polar_rnn      0.002200  0.002638
# ...

# %%
# Results for the top hyperparams
df.groupby(['DATASET', 'MODEL'])['final_NRMSE', 'final_ND'].min()
# Out:
# /tmp/ipykernel_25960/1549991816.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['DATASET', 'MODEL'])['final_NRMSE', 'final_ND'].min()
#                        final_NRMSE  final_ND
# DATASET   MODEL
# rossmann  mlp              0.15605   0.10551
#           polar_dense      0.14240   0.09702
#           polar_rnn        0.14415   0.10148
#           rnn              0.15190   0.10121
# synthetic mlp              0.02360   0.01829
#           polar_dense      0.03058   0.02451
#           polar_rnn        0.04596   0.03788
#           rnn              0.00529   0.00414
# walmart   mlp              0.12536   0.07229
#           polar_dense      0.15396   0.08528
#           polar_rnn        0.13947   0.07249
#           rnn              0.15196   0.08480
